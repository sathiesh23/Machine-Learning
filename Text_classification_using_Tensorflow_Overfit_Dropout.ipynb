# %% [markdown]
# **Overfitting Model**: Excess capacity (more parameters) in learning data.
#
# **Training Error -> Decreases, Validation Error -> Increases**

# %% [markdown]
# Dataset: IMDB Movie Review Dataset

# %%
# import the necessary packages
from __future__ import absolute_import, division, print_function, unicode_literals
from matplotlib import pyplot as plt
import numpy as np
#!pip install tensorflow==2.1.0
import tensorflow as tf
from tensorflow import keras

# %%
# Load the dataset from keras package
NUM_WORDS=10000
(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)
print("Training entries: {}, Test entries: {}".format(len(train_data), len(test_data)))
print(train_data[:10])
print(train_labels[:10])
# Out:
# ...
# 17464789/17464789 [==============================] - 2s 0us/step
# Training entries: 25000, Test entries: 25000
# ...

# %%
# Create a function for Multi-hot Sequences
# Multihot encoding turns our list of words into a vector of 0's and 1's
# Set specific indices of results[i] is set to 1
def multi_hot_sequences(sequences, dimension):
  results = np.zeros((len(sequences), dimension))
  for i, word_indices in enumerate(sequences):
    results[i, word_indices]=1.0
  return results

# %%
# 10000 dimension vector is created
# it is done to ensure that all the messages are of equal length
train_data = multi_hot_sequences(train_data, dimension = NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)
print(train_data[0])
plt.plot(train_data[0])
# Out:
# [0. 1. 1. ... 0. 0. 0.]

# %% [markdown]
# ## Demonstrate Overfitting:

# %%
# Create a Standard baseline model
std_model = tf.keras.Sequential()
std_model.add(tf.keras.layers.Dense(16, activation='relu', input_shape = (NUM_WORDS,)))
#std_model.add(tf.keras.layers.Dense(16, activation='relu'))
std_model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

std_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 16)                160016
#
#  dense_1 (Dense)             (None, 1)                 17
#
# ...
# Total params: 160,033
# Trainable params: 160,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set the optimizer and loss function to the model
std_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model for 10 epochs
std_history = std_model.fit(train_data, train_labels, epochs = 10, batch_size=512, validation_data=(test_data,test_labels), verbose=2)
# Out:
# Epoch 1/10
# 49/49 - 5s - loss: 0.4532 - accuracy: 0.8232 - val_loss: 0.3409 - val_accuracy: 0.8770 - 5s/epoch - 105ms/step
# Epoch 2/10
# 49/49 - 1s - loss: 0.2633 - accuracy: 0.9100 - val_loss: 0.2949 - val_accuracy: 0.8864 - 1s/epoch - 22ms/step
# Epoch 3/10
# 49/49 - 1s - loss: 0.2084 - accuracy: 0.9308 - val_loss: 0.2870 - val_accuracy: 0.8850 - 1s/epoch - 23ms/step
# Epoch 4/10
# 49/49 - 1s - loss: 0.1767 - accuracy: 0.9417 - val_loss: 0.2860 - val_accuracy: 0.8858 - 1s/epoch - 22ms/step
# Epoch 5/10
# 49/49 - 1s - loss: 0.1542 - accuracy: 0.9506 - val_loss: 0.2964 - val_accuracy: 0.8811 - 1s/epoch - 24ms/step
# Epoch 6/10
# 49/49 - 1s - loss: 0.1365 - accuracy: 0.9572 - val_loss: 0.3039 - val_accuracy: 0.8797 - 1s/epoch - 22ms/step
# Epoch 7/10
# 49/49 - 1s - loss: 0.1219 - accuracy: 0.9622 - val_loss: 0.3156 - val_accuracy: 0.8777 - 1s/epoch - 22ms/step
# Epoch 8/10
# ...

# %% [markdown]
# ## Create a Large Network

# %%
# Create a Large model
large_model = tf.keras.Sequential()
large_model.add(tf.keras.layers.Dense(50, activation='relu', input_shape = (NUM_WORDS,)))
#large_model.add(tf.keras.layers.Dense(100, activation='relu'))
large_model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

large_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 50)                500050
#
#  dense_3 (Dense)             (None, 1)                 51
#
# ...
# Total params: 500,101
# Trainable params: 500,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set the optimizer and loss function to the model
large_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'binary_crossentropy'])

# %%
# Train the model for 10 epochs
large_history = large_model.fit(train_data, train_labels, epochs = 10, batch_size=512, validation_data=(test_data,test_labels), verbose=2)
# Out:
# Epoch 1/10
# 49/49 - 3s - loss: 0.4166 - accuracy: 0.8332 - binary_crossentropy: 0.4166 - val_loss: 0.3041 - val_accuracy: 0.8826 - val_binary_crossentropy: 0.3041 - 3s/epoch - 62ms/step
# Epoch 2/10
# 49/49 - 1s - loss: 0.2251 - accuracy: 0.9190 - binary_crossentropy: 0.2251 - val_loss: 0.2830 - val_accuracy: 0.8872 - val_binary_crossentropy: 0.2830 - 1s/epoch - 22ms/step
# Epoch 3/10
# 49/49 - 1s - loss: 0.1727 - accuracy: 0.9402 - binary_crossentropy: 0.1727 - val_loss: 0.2918 - val_accuracy: 0.8834 - val_binary_crossentropy: 0.2918 - 1s/epoch - 22ms/step
# Epoch 4/10
# 49/49 - 1s - loss: 0.1424 - accuracy: 0.9545 - binary_crossentropy: 0.1424 - val_loss: 0.3062 - val_accuracy: 0.8801 - val_binary_crossentropy: 0.3062 - 1s/epoch - 23ms/step
# Epoch 5/10
# 49/49 - 1s - loss: 0.1197 - accuracy: 0.9621 - binary_crossentropy: 0.1197 - val_loss: 0.3308 - val_accuracy: 0.8740 - val_binary_crossentropy: 0.3308 - 1s/epoch - 23ms/step
# Epoch 6/10
# ...

# %%
# Plot the models
plt.plot(std_history.history['loss'], 'r', large_history.history['loss'], 'g')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.legend(['std_model','large_model'])
plt.show()

# %%
# Plot the models
plt.plot(std_history.history['val_loss'], 'r--', large_history.history['val_loss'], 'g--')
plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend(['std_model','large_model'])
plt.show()

# %% [markdown]
# ## Stratergies to prevent Overfitting by Models:
#
# 1. Get more data to minimize the overfitting by Models
# 2. Add weight regularization:
#
#   i. **L1 Regularization:** The cost is added proportional to the absolute value of the weight coefficients (L1 norm of the weights).
#
#   ii. **L2 Regularization:** The cost is added proportional to the square of the value of the weight coefficients (Squared L2 Norm of the weights). Example: **l2(0.001)** = 0.001 * weight_coefficient_value ** 2, where regularization rate = 0.001.
#
# 3. Add a dropout layer to the model:
#
#  *   Randomly "Dropping out" a number of output features in a layer during training process.
#  *   The vector elements (few) will be replaced by 0 after a dropout condition.
#  *   The dropout value is usually set between 0.2 to 0.5 (20% to 50%).
#  *   At Test time, no units are dropped out. Instead, the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active during the training process.

# %% [markdown]
# ### Add a Dropout layer to the Model

# %%
# Add the Dropout layers to the Large model
dpt_model = tf.keras.Sequential()
dpt_model.add(tf.keras.layers.Dense(50, activation='relu', input_shape = (NUM_WORDS,)))
dpt_model.add(tf.keras.layers.Dropout(0.5))
#dpt_model.add(tf.keras.layers.Dense(512, activation='relu'))
#dpt_model.add(tf.keras.layers.Dropout(0.5))
dpt_model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

dpt_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 50)                500050
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_5 (Dense)             (None, 1)                 51
#
# ...
# Total params: 500,101
# Trainable params: 500,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set the optimizer and loss function to the model
dpt_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'binary_crossentropy'])

# %%
# Train the model for 10 epochs
dpt_model_history = dpt_model.fit(train_data, train_labels, epochs = 10, batch_size=512, validation_data=(test_data,test_labels), verbose=2)
# Out:
# Epoch 1/10
# 49/49 - 4s - loss: 0.4587 - accuracy: 0.8000 - binary_crossentropy: 0.4587 - val_loss: 0.3224 - val_accuracy: 0.8808 - val_binary_crossentropy: 0.3224 - 4s/epoch - 80ms/step
# Epoch 2/10
# 49/49 - 1s - loss: 0.2656 - accuracy: 0.9026 - binary_crossentropy: 0.2656 - val_loss: 0.2830 - val_accuracy: 0.8883 - val_binary_crossentropy: 0.2830 - 1s/epoch - 30ms/step
# Epoch 3/10
# 49/49 - 1s - loss: 0.2103 - accuracy: 0.9234 - binary_crossentropy: 0.2103 - val_loss: 0.2760 - val_accuracy: 0.8903 - val_binary_crossentropy: 0.2760 - 1s/epoch - 22ms/step
# Epoch 4/10
# 49/49 - 1s - loss: 0.1751 - accuracy: 0.9387 - binary_crossentropy: 0.1751 - val_loss: 0.2806 - val_accuracy: 0.8870 - val_binary_crossentropy: 0.2806 - 1s/epoch - 22ms/step
# Epoch 5/10
# 49/49 - 1s - loss: 0.1495 - accuracy: 0.9482 - binary_crossentropy: 0.1495 - val_loss: 0.2940 - val_accuracy: 0.8838 - val_binary_crossentropy: 0.2940 - 1s/epoch - 25ms/step
# Epoch 6/10
# ...

# %%
# Plot the models
plt.plot(dpt_model_history.history['val_loss'], 'v--', large_history.history['val_loss'], 'g--')
plt.xlabel('Epochs')
plt.ylabel('Validation loss')
plt.legend(['dpt_model_large','large_model'])
plt.show()
